# %% [markdown]
# # Cost of a turbine

# %% [markdown]
# First, import the WISDEM code that will model our costs. Also import the pieces of OpenMDAO that we'll need for the optimization.

# %%
from wisdem.turbine_costsse.turbine_costsse_2015 import Turbine_CostsSE_2015
from openmdao.api import Problem

# %% [markdown]
# Before we input the variables into our model, we need to perform the following steps:
#
# 1. Create an instance of `Turbine_CostsSE_2015`. This will calculate our cost. When we instantiate it it, we set `verbosity` to `True` so we can view detailed outputs as it performs our optimization.
#
# 1. OpenMDAO will be running the optimization, so we create the `Problem` named `prob` for OpenMDAO to solve. The problem is our `turbine`
#
# 1. We run `prob.setup()` so that OpenMDAO will initialize our problem.

# %%
turbine = Turbine_CostsSE_2015(verbosity=True)
prob = Problem(turbine)
prob.setup()

# %% [markdown]
# Now we can set the independent variables for our model. Masses are in kilograms. All values are `float` data type.

# %%
# Masses
prob['blade_mass'] = 17650.67
prob['hub_mass'] = 31644.5
prob['pitch_system_mass'] = 17004.0
prob['spinner_mass'] = 1810.5
prob['lss_mass'] = 31257.3
prob['main_bearing_mass'] = 9731.41 / 2
prob['gearbox_mass'] = 30237.60
prob['hss_mass'] = 1492.45
prob['generator_mass'] = 16699.85
prob['bedplate_mass'] = 93090.6
prob['yaw_mass'] = 11878.24
prob['tower_mass'] = 434559.0
prob['vs_electronics_mass'] = 1000.0
prob['hvac_mass'] = 1000.0
prob['cover_mass'] = 1000.0
prob['platforms_mass'] = 1000.0
prob['transformer_mass'] = 1000.0

# Other inputs
prob['machine_rating'] = 5000.0   # kW
prob['blade_number'] = 3          # Number of rotor blades
prob['crane'] = True              # Flag for presence of onboard crane
prob['main_bearing_number'] = 2   # Number of main bearings

# %% [markdown]
# Finally, we get to run our model.

# %%
prob.run_driver()
# Out:
# ################################################
# Computation of costs of the main turbine components from TurbineCostSE
# Blade cost              257.700 k USD       mass 17650.670 kg
# Pitch system cost       375.788 k USD       mass 17004.000 kg
# Hub cost                123.414 k USD       mass 31644.500 kg
# Spinner cost            20.097 k USD       mass 1810.500 kg
# ------------------------------------------------
# Rotor cost              1292.398 k USD       mass 103411.010 kg
#
# LSS cost                371.962 k USD       mass 31257.300 kg
# Main bearing cost       43.791 k USD       mass 4865.705 kg
# Gearbox cost            390.065 k USD       mass 30237.600 kg
# HSS cost                10.149 k USD       mass 1492.450 kg
# Generator cost          207.078 k USD       mass 16699.850 kg
# Bedplate cost           269.963 k USD       mass 93090.600 kg
# Yaw system cost         98.589 k USD       mass 11878.240 kg
# HVAC cost               124.000 k USD       mass 1000.000 kg
# Nacelle cover cost      5.700 k USD       mass 1000.000 kg
# Electr connection cost  209.250 k USD
# Controls cost           105.750 k USD
# Other main frame cost   -22.200 k USD
# Transformer cost        18.800 k USD       mass 1000.000 kg
# ------------------------------------------------
# Nacelle cost            1895.489 k USD       mass 197387.450 kg
#
# Tower cost              1260.221 k USD       mass 434559.000 kg
# ------------------------------------------------
# ------------------------------------------------
# Turbine cost            4448.107 k USD       mass 735357.460 kg
# ################################################
# False

# %% [markdown]
# `turbine._outputs` is a dictionary like object with key-value pairs. As an example, after this model runs you can run the following statement to access the rating of the turbine in kilowatts.
#
# Note that, even though the rating is a non-vector value, the value is in a NumPy array. Of course, vectors are returned in NumPy arrays as well.

# %%
turbine._outputs['sharedIndeps.machine_rating']
# Out:
# array([5000.])

# %% [markdown]
# But what if we want to see all the inputs at once?

# %%
prob.model.list_inputs(units=True)
# Out:
# 143 Input(s) in 'model'
# -----------------------
#
# varname                                    value          units
# -----------------------------------------  -------------  ------
# top
#   blade_c
#     blade_mass                             [17650.67]     kg
#     blade_mass_cost_coeff                  [14.6]         USD/kg
#     blade_cost_external                    [0.]           USD
#   hub_c
#     hub_mass                               [31644.5]      kg
#     hub_mass_cost_coeff                    [3.9]          USD/kg
#   pitch_c
#     pitch_system_mass                      [17004.]       kg
#     pitch_system_mass_cost_coeff           [22.1]         USD/kg
#   spinner_c
#     spinner_mass                           [1810.5]       kg
#     spinner_mass_cost_coeff                [11.1]         USD/kg
#   hub_adder
#     hub_cost                               [123413.55]    USD
#     hub_mass                               [31644.5]      kg
#     pitch_system_cost                      [375788.4]     USD
#     pitch_system_mass                      [17004.]       kg
#     spinner_cost                           [20096.55]     USD
#     spinner_mass                           [1810.5]       kg
#     hub_assemblyCostMultiplier             [0.]           None
#     hub_overheadCostMultiplier             [0.]           None
#     hub_profitMultiplier                   [0.]           None
#     hub_transportMultiplier                [0.]           None
#   rotor_adder
#     blade_cost                             [257699.782]   USD
#     blade_mass                             [17650.67]     kg
#     hub_system_cost                        [519298.5]     USD
#     hub_system_mass_tcc                    [50459.]       kg
#     blade_number                           3
#   lss_c
#     lss_mass                               [31257.3]      kg
#     lss_mass_cost_coeff                    [11.9]         USD/kg
#   bearing_c
#     main_bearing_mass                      [4865.705]     kg
#     bearings_mass_cost_coeff               [4.5]          USD/kg
#     main_bearing_number                    2
#   gearbox_c
#     gearbox_mass                           [30237.6]      kg
#     gearbox_mass_cost_coeff                [12.9]         USD/kg
#   hss_c
#     hss_mass                               [1492.45]      kg
#     hss_mass_cost_coeff                    [6.8]          USD/kg
#   generator_c
#     generator_mass                         [16699.85]     kg
#     generator_mass_cost_coeff              [12.4]         USD/kg
#   bedplate_c
#     bedplate_mass                          [93090.6]      kg
#     bedplate_mass_cost_coeff               [2.9]          USD/kg
#   yaw_c
#     yaw_mass                               [11878.24]     kg
#     yaw_mass_cost_coeff                    [8.3]          USD/kg
#   hvac_c
#     hvac_mass                              [1000.]        kg
#     hvac_mass_cost_coeff                   [124.]         USD/kg
#   controls_c
#     machine_rating                         [5000.]        kW
#     controls_machine_rating_cost_coeff     [21.15]        USD/kW
#   vs_c
#     vs_electronics_mass                    [1000.]        kg
#     vs_electronics_mass_cost_coeff         [18.8]         USD/kg
#   elec_c
#     machine_rating                         [5000.]        kW
#     elec_connec_machine_rating_cost_coeff  [41.85]        USD/kW
#   cover_c
#     cover_mass                             [1000.]        kg
#     cover_mass_cost_coeff                  [5.7]          USD/kg
#   other_c
#     platforms_mass                         [1000.]        kg
#     platforms_mass_cost_coeff              [17.1]         USD/kg
#     crane_cost                             [12000.]       USD
#     crane                                  True
#   transformer_c
#     transformer_mass                       [1000.]        kg
#     transformer_mass_cost_coeff            [18.8]         USD/kg
#   nacelle_adder
#     lss_cost                               [371961.87]    USD
#     lss_mass                               [31257.3]      kg
#     main_bearing_cost                      [43791.345]    USD
#     main_bearing_mass                      [4865.705]     kg
#     gearbox_cost                           [390065.04]    USD
#     gearbox_mass                           [30237.6]      kg
#     hss_cost                               [10148.66]     USD
#     hss_mass                               [1492.45]      kg
#     generator_cost                         [207078.14]    USD
#     generator_mass                         [16699.85]     kg
#     bedplate_cost                          [269962.74]    USD
#     bedplate_mass                          [93090.6]      kg
#     yaw_system_cost                        [98589.392]    USD
#     yaw_mass                               [11878.24]     kg
#     vs_cost                                [18800.]       USD
#     vs_mass                                [0.]           kg
#     hvac_cost                              [124000.]      USD
#     hvac_mass                              [1000.]        kg
#     cover_cost                             [5700.]        USD
#     cover_mass                             [1000.]        kg
#     elec_cost                              [209250.]      USD
#     controls_cost                          [105750.]      USD
#     other_cost                             [-22200.]      USD
#     transformer_cost                       [18800.]       USD
#     transformer_mass                       [1000.]        kg
#     nacelle_assemblyCostMultiplier         [0.]           None
#     nacelle_overheadCostMultiplier         [0.]           None
#     nacelle_profitMultiplier               [0.]           None
#     nacelle_transportMultiplier            [0.]           None
#     main_bearing_number                    2
#   tower_c
#     tower_mass                             [434559.]      kg
#     tower_mass_cost_coeff                  [2.9]          USD/kg
#     tower_cost_external                    [0.]           USD
#   tower_adder
#     tower_parts_cost                       [1260221.1]    USD
#     tower_assemblyCostMultiplier           [0.]           None
#     tower_overheadCostMultiplier           [0.]           None
#     tower_profitMultiplier                 [0.]           None
#     tower_transportMultiplier              [0.]           None
#   turbine_c
#     rotor_cost                             [1292397.846]  USD
#     rotor_mass_tcc                         [103411.01]    kg
#     nacelle_cost                           [1895488.532]  USD
#     nacelle_mass_tcc                       [197387.45]    kg
#     tower_cost                             [1260221.1]    USD
#     tower_mass                             [434559.]      kg
#     machine_rating                         [5000.]        kW
#     turbine_assemblyCostMultiplier         [0.]           None
#     turbine_overheadCostMultiplier         [0.]           None
#     turbine_profitMultiplier               [0.]           None
#     turbine_transportMultiplier            [0.]           None
#   outputs
#     blade_cost                             [257699.782]   USD
#     blade_mass                             [17650.67]     kg
#     hub_cost                               [123413.55]    USD
#     hub_mass                               [31644.5]      kg
#     pitch_system_cost                      [375788.4]     USD
#     pitch_system_mass                      [17004.]       kg
#     spinner_cost                           [20096.55]     USD
#     spinner_mass                           [1810.5]       kg
#     lss_cost                               [371961.87]    USD
#     lss_mass                               [31257.3]      kg
#     main_bearing_cost                      [43791.345]    USD
#     main_bearing_mass                      [4865.705]     kg
#     gearbox_cost                           [390065.04]    USD
#     gearbox_mass                           [30237.6]      kg
#     hss_cost                               [10148.66]     USD
#     hss_mass                               [1492.45]      kg
#     generator_cost                         [207078.14]    USD
#     generator_mass                         [16699.85]     kg
#     bedplate_cost                          [269962.74]    USD
#     bedplate_mass                          [93090.6]      kg
#     yaw_system_cost                        [98589.392]    USD
#     yaw_mass                               [11878.24]     kg
#     hvac_cost                              [124000.]      USD
#     hvac_mass                              [1000.]        kg
#     cover_cost                             [5700.]        USD
#     cover_mass                             [1000.]        kg
#     elec_cost                              [209250.]      USD
#     controls_cost                          [105750.]      USD
#     other_cost                             [-22200.]      USD
#     transformer_cost                       [18800.]       USD
#     transformer_mass                       [1000.]        kg
#     rotor_cost                             [1292397.846]  USD
#     rotor_mass_tcc                         [103411.01]    kg
#     nacelle_cost                           [1895488.532]  USD
#     nacelle_mass_tcc                       [197387.45]    kg
#     tower_cost                             [1260221.1]    USD
#     tower_mass                             [434559.]      kg
#     turbine_cost                           [4448107.478]  USD
#     turbine_mass_tcc                       [735357.46]    kg
# [('blade_c.blade_mass', {'value': array([17650.67]), 'units': 'kg'}),
#  ('blade_c.blade_mass_cost_coeff',
#   {'value': array([14.6]), 'units': 'USD/kg'}),
#  ('blade_c.blade_cost_external', {'value': array([0.]), 'units': 'USD'}),
#  ('hub_c.hub_mass', {'value': array([31644.5]), 'units': 'kg'}),
#  ('hub_c.hub_mass_cost_coeff', {'value': array([3.9]), 'units': 'USD/kg'}),
#  ('pitch_c.pitch_system_mass', {'value': array([17004.]), 'units': 'kg'}),
#  ('pitch_c.pitch_system_mass_cost_coeff',
#   {'value': array([22.1]), 'units': 'USD/kg'}),
#  ('spinner_c.spinner_mass', {'value': array([1810.5]), 'units': 'kg'}),
#  ('spinner_c.spinner_mass_cost_coeff',
#   {'value': array([11.1]), 'units': 'USD/kg'}),
#  ('hub_adder.hub_cost', {'value': array([123413.55]), 'units': 'USD'}),
#  ('hub_adder.hub_mass', {'value': array([31644.5]), 'units': 'kg'}),
#  ('hub_adder.pitch_system_cost', {'value': array([375788.4]), 'units': 'USD'}),
#  ('hub_adder.pitch_system_mass', {'value': array([17004.]), 'units': 'kg'}),
#  ('hub_adder.spinner_cost', {'value': array([20096.55]), 'units': 'USD'}),
#  ('hub_adder.spinner_mass', {'value': array([1810.5]), 'units': 'kg'}),
#  ('hub_adder.hub_assemblyCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('hub_adder.hub_overheadCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('hub_adder.hub_profitMultiplier', {'value': array([0.]), 'units': None}),
#  ('hub_adder.hub_transportMultiplier', {'value': array([0.]), 'units': None}),
#  ('rotor_adder.blade_cost', {'value': array([257699.782]), 'units': 'USD'}),
#  ('rotor_adder.blade_mass', {'value': array([17650.67]), 'units': 'kg'}),
#  ('rotor_adder.hub_system_cost', {'value': array([519298.5]), 'units': 'USD'}),
#  ('rotor_adder.hub_system_mass_tcc',
#   {'value': array([50459.]), 'units': 'kg'}),
#  ('lss_c.lss_mass', {'value': array([31257.3]), 'units': 'kg'}),
#  ('lss_c.lss_mass_cost_coeff', {'value': array([11.9]), 'units': 'USD/kg'}),
#  ('bearing_c.main_bearing_mass', {'value': array([4865.705]), 'units': 'kg'}),
#  ('bearing_c.bearings_mass_cost_coeff',
#   {'value': array([4.5]), 'units': 'USD/kg'}),
#  ('gearbox_c.gearbox_mass', {'value': array([30237.6]), 'units': 'kg'}),
#  ('gearbox_c.gearbox_mass_cost_coeff',
#   {'value': array([12.9]), 'units': 'USD/kg'}),
#  ('hss_c.hss_mass', {'value': array([1492.45]), 'units': 'kg'}),
#  ('hss_c.hss_mass_cost_coeff', {'value': array([6.8]), 'units': 'USD/kg'}),
#  ('generator_c.generator_mass', {'value': array([16699.85]), 'units': 'kg'}),
#  ('generator_c.generator_mass_cost_coeff',
#   {'value': array([12.4]), 'units': 'USD/kg'}),
#  ('bedplate_c.bedplate_mass', {'value': array([93090.6]), 'units': 'kg'}),
#  ('bedplate_c.bedplate_mass_cost_coeff',
#   {'value': array([2.9]), 'units': 'USD/kg'}),
#  ('yaw_c.yaw_mass', {'value': array([11878.24]), 'units': 'kg'}),
#  ('yaw_c.yaw_mass_cost_coeff', {'value': array([8.3]), 'units': 'USD/kg'}),
#  ('hvac_c.hvac_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('hvac_c.hvac_mass_cost_coeff', {'value': array([124.]), 'units': 'USD/kg'}),
#  ('controls_c.machine_rating', {'value': array([5000.]), 'units': 'kW'}),
#  ('controls_c.controls_machine_rating_cost_coeff',
#   {'value': array([21.15]), 'units': 'USD/kW'}),
#  ('vs_c.vs_electronics_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('vs_c.vs_electronics_mass_cost_coeff',
#   {'value': array([18.8]), 'units': 'USD/kg'}),
#  ('elec_c.machine_rating', {'value': array([5000.]), 'units': 'kW'}),
#  ('elec_c.elec_connec_machine_rating_cost_coeff',
#   {'value': array([41.85]), 'units': 'USD/kW'}),
#  ('cover_c.cover_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('cover_c.cover_mass_cost_coeff', {'value': array([5.7]), 'units': 'USD/kg'}),
#  ('other_c.platforms_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('other_c.platforms_mass_cost_coeff',
#   {'value': array([17.1]), 'units': 'USD/kg'}),
#  ('other_c.crane_cost', {'value': array([12000.]), 'units': 'USD'}),
#  ('transformer_c.transformer_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('transformer_c.transformer_mass_cost_coeff',
#   {'value': array([18.8]), 'units': 'USD/kg'}),
#  ('nacelle_adder.lss_cost', {'value': array([371961.87]), 'units': 'USD'}),
#  ('nacelle_adder.lss_mass', {'value': array([31257.3]), 'units': 'kg'}),
#  ('nacelle_adder.main_bearing_cost',
#   {'value': array([43791.345]), 'units': 'USD'}),
#  ('nacelle_adder.main_bearing_mass',
#   {'value': array([4865.705]), 'units': 'kg'}),
#  ('nacelle_adder.gearbox_cost', {'value': array([390065.04]), 'units': 'USD'}),
#  ('nacelle_adder.gearbox_mass', {'value': array([30237.6]), 'units': 'kg'}),
#  ('nacelle_adder.hss_cost', {'value': array([10148.66]), 'units': 'USD'}),
#  ('nacelle_adder.hss_mass', {'value': array([1492.45]), 'units': 'kg'}),
#  ('nacelle_adder.generator_cost',
#   {'value': array([207078.14]), 'units': 'USD'}),
#  ('nacelle_adder.generator_mass', {'value': array([16699.85]), 'units': 'kg'}),
#  ('nacelle_adder.bedplate_cost',
#   {'value': array([269962.74]), 'units': 'USD'}),
#  ('nacelle_adder.bedplate_mass', {'value': array([93090.6]), 'units': 'kg'}),
#  ('nacelle_adder.yaw_system_cost',
#   {'value': array([98589.392]), 'units': 'USD'}),
#  ('nacelle_adder.yaw_mass', {'value': array([11878.24]), 'units': 'kg'}),
#  ('nacelle_adder.vs_cost', {'value': array([18800.]), 'units': 'USD'}),
#  ('nacelle_adder.vs_mass', {'value': array([0.]), 'units': 'kg'}),
#  ('nacelle_adder.hvac_cost', {'value': array([124000.]), 'units': 'USD'}),
#  ('nacelle_adder.hvac_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('nacelle_adder.cover_cost', {'value': array([5700.]), 'units': 'USD'}),
#  ('nacelle_adder.cover_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('nacelle_adder.elec_cost', {'value': array([209250.]), 'units': 'USD'}),
#  ('nacelle_adder.controls_cost', {'value': array([105750.]), 'units': 'USD'}),
#  ('nacelle_adder.other_cost', {'value': array([-22200.]), 'units': 'USD'}),
#  ('nacelle_adder.transformer_cost',
#   {'value': array([18800.]), 'units': 'USD'}),
#  ('nacelle_adder.transformer_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('nacelle_adder.nacelle_assemblyCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('nacelle_adder.nacelle_overheadCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('nacelle_adder.nacelle_profitMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('nacelle_adder.nacelle_transportMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('tower_c.tower_mass', {'value': array([434559.]), 'units': 'kg'}),
#  ('tower_c.tower_mass_cost_coeff', {'value': array([2.9]), 'units': 'USD/kg'}),
#  ('tower_c.tower_cost_external', {'value': array([0.]), 'units': 'USD'}),
#  ('tower_adder.tower_parts_cost',
#   {'value': array([1260221.1]), 'units': 'USD'}),
#  ('tower_adder.tower_assemblyCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('tower_adder.tower_overheadCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('tower_adder.tower_profitMultiplier', {'value': array([0.]), 'units': None}),
#  ('tower_adder.tower_transportMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('turbine_c.rotor_cost', {'value': array([1292397.846]), 'units': 'USD'}),
#  ('turbine_c.rotor_mass_tcc', {'value': array([103411.01]), 'units': 'kg'}),
#  ('turbine_c.nacelle_cost', {'value': array([1895488.532]), 'units': 'USD'}),
#  ('turbine_c.nacelle_mass_tcc', {'value': array([197387.45]), 'units': 'kg'}),
#  ('turbine_c.tower_cost', {'value': array([1260221.1]), 'units': 'USD'}),
#  ('turbine_c.tower_mass', {'value': array([434559.]), 'units': 'kg'}),
#  ('turbine_c.machine_rating', {'value': array([5000.]), 'units': 'kW'}),
#  ('turbine_c.turbine_assemblyCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('turbine_c.turbine_overheadCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('turbine_c.turbine_profitMultiplier', {'value': array([0.]), 'units': None}),
#  ('turbine_c.turbine_transportMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('outputs.blade_cost', {'value': array([257699.782]), 'units': 'USD'}),
#  ('outputs.blade_mass', {'value': array([17650.67]), 'units': 'kg'}),
#  ('outputs.hub_cost', {'value': array([123413.55]), 'units': 'USD'}),
#  ('outputs.hub_mass', {'value': array([31644.5]), 'units': 'kg'}),
#  ('outputs.pitch_system_cost', {'value': array([375788.4]), 'units': 'USD'}),
#  ('outputs.pitch_system_mass', {'value': array([17004.]), 'units': 'kg'}),
#  ('outputs.spinner_cost', {'value': array([20096.55]), 'units': 'USD'}),
#  ('outputs.spinner_mass', {'value': array([1810.5]), 'units': 'kg'}),
#  ('outputs.lss_cost', {'value': array([371961.87]), 'units': 'USD'}),
#  ('outputs.lss_mass', {'value': array([31257.3]), 'units': 'kg'}),
#  ('outputs.main_bearing_cost', {'value': array([43791.345]), 'units': 'USD'}),
#  ('outputs.main_bearing_mass', {'value': array([4865.705]), 'units': 'kg'}),
#  ('outputs.gearbox_cost', {'value': array([390065.04]), 'units': 'USD'}),
#  ('outputs.gearbox_mass', {'value': array([30237.6]), 'units': 'kg'}),
#  ('outputs.hss_cost', {'value': array([10148.66]), 'units': 'USD'}),
#  ('outputs.hss_mass', {'value': array([1492.45]), 'units': 'kg'}),
#  ('outputs.generator_cost', {'value': array([207078.14]), 'units': 'USD'}),
#  ('outputs.generator_mass', {'value': array([16699.85]), 'units': 'kg'}),
#  ('outputs.bedplate_cost', {'value': array([269962.74]), 'units': 'USD'}),
#  ('outputs.bedplate_mass', {'value': array([93090.6]), 'units': 'kg'}),
#  ('outputs.yaw_system_cost', {'value': array([98589.392]), 'units': 'USD'}),
#  ('outputs.yaw_mass', {'value': array([11878.24]), 'units': 'kg'}),
#  ('outputs.hvac_cost', {'value': array([124000.]), 'units': 'USD'}),
#  ('outputs.hvac_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('outputs.cover_cost', {'value': array([5700.]), 'units': 'USD'}),
#  ('outputs.cover_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('outputs.elec_cost', {'value': array([209250.]), 'units': 'USD'}),
#  ('outputs.controls_cost', {'value': array([105750.]), 'units': 'USD'}),
#  ('outputs.other_cost', {'value': array([-22200.]), 'units': 'USD'}),
#  ('outputs.transformer_cost', {'value': array([18800.]), 'units': 'USD'}),
#  ('outputs.transformer_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('outputs.rotor_cost', {'value': array([1292397.846]), 'units': 'USD'}),
#  ('outputs.rotor_mass_tcc', {'value': array([103411.01]), 'units': 'kg'}),
#  ('outputs.nacelle_cost', {'value': array([1895488.532]), 'units': 'USD'}),
#  ('outputs.nacelle_mass_tcc', {'value': array([197387.45]), 'units': 'kg'}),
#  ('outputs.tower_cost', {'value': array([1260221.1]), 'units': 'USD'}),
#  ('outputs.tower_mass', {'value': array([434559.]), 'units': 'kg'}),
#  ('outputs.turbine_cost', {'value': array([4448107.478]), 'units': 'USD'}),
#  ('outputs.turbine_mass_tcc', {'value': array([735357.46]), 'units': 'kg'}),
#  ('rotor_adder.blade_number', {'value': 3, 'units': ''}),
#  ('bearing_c.main_bearing_number', {'value': 2, 'units': ''}),
#  ('other_c.crane', {'value': True, 'units': ''}),
#  ('nacelle_adder.main_bearing_number', {'value': 2, 'units': ''})]

# %% [markdown]
# And to see the outputs:

# %%
prob.model.list_outputs(units=True)
# Out:
# 87 Explicit Output(s) in 'model'
# --------------------------------
#
# varname                                    value          units
# -----------------------------------------  -------------  ------
# top
#   sharedIndeps
#     machine_rating                         [5000.]        kW
#     blade_mass                             [17650.67]     kg
#     hub_mass                               [31644.5]      kg
#     pitch_system_mass                      [17004.]       kg
#     spinner_mass                           [1810.5]       kg
#     lss_mass                               [31257.3]      kg
#     bearings_mass                          [0.]           kg
#     gearbox_mass                           [30237.6]      kg
#     main_bearing_mass                      [4865.705]     kg
#     hss_mass                               [1492.45]      kg
#     generator_mass                         [16699.85]     kg
#     bedplate_mass                          [93090.6]      kg
#     yaw_mass                               [11878.24]     kg
#     vs_electronics_mass                    [1000.]        kg
#     hvac_mass                              [1000.]        kg
#     cover_mass                             [1000.]        kg
#     platforms_mass                         [1000.]        kg
#     transformer_mass                       [1000.]        kg
#     tower_mass                             [434559.]      kg
#     main_bearing_number                    2
#     crane                                  True
#   indeps
#     blade_mass_cost_coeff                  [14.6]         USD/kg
#     hub_mass_cost_coeff                    [3.9]          USD/kg
#     pitch_system_mass_cost_coeff           [22.1]         USD/kg
#     spinner_mass_cost_coeff                [11.1]         USD/kg
#     lss_mass_cost_coeff                    [11.9]         USD/kg
#     bearings_mass_cost_coeff               [4.5]          USD/kg
#     gearbox_mass_cost_coeff                [12.9]         USD/kg
#     hss_mass_cost_coeff                    [6.8]          USD/kg
#     generator_mass_cost_coeff              [12.4]         USD/kg
#     bedplate_mass_cost_coeff               [2.9]          USD/kg
#     yaw_mass_cost_coeff                    [8.3]          USD/kg
#     vs_electronics_mass_cost_coeff         [18.8]         USD/kg
#     hvac_mass_cost_coeff                   [124.]         USD/kg
#     cover_mass_cost_coeff                  [5.7]          USD/kg
#     elec_connec_machine_rating_cost_coeff  [41.85]        USD/kW
#     platforms_mass_cost_coeff              [17.1]         USD/kg
#     base_hardware_cost_coeff               [0.7]          USD/kg
#     transformer_mass_cost_coeff            [18.8]         USD/kg
#     tower_mass_cost_coeff                  [2.9]          USD/kg
#     controls_machine_rating_cost_coeff     [21.15]        USD/kW
#     crane_cost                             [12000.]       USD
#     hub_assemblyCostMultiplier             [0.]           None
#     hub_overheadCostMultiplier             [0.]           None
#     nacelle_assemblyCostMultiplier         [0.]           None
#     nacelle_overheadCostMultiplier         [0.]           None
#     tower_assemblyCostMultiplier           [0.]           None
#     tower_overheadCostMultiplier           [0.]           None
#     turbine_assemblyCostMultiplier         [0.]           None
#     turbine_overheadCostMultiplier         [0.]           None
#     hub_profitMultiplier                   [0.]           None
#     nacelle_profitMultiplier               [0.]           None
#     tower_profitMultiplier                 [0.]           None
#     turbine_profitMultiplier               [0.]           None
#     hub_transportMultiplier                [0.]           None
#     nacelle_transportMultiplier            [0.]           None
#     tower_transportMultiplier              [0.]           None
#     turbine_transportMultiplier            [0.]           None
#   blade_c
#     blade_cost                             [257699.782]   USD
#   hub_c
#     hub_cost                               [123413.55]    USD
#   pitch_c
#     pitch_system_cost                      [375788.4]     USD
#   spinner_c
#     spinner_cost                           [20096.55]     USD
#   hub_adder
#     hub_system_mass_tcc                    [50459.]       kg
#     hub_system_cost                        [519298.5]     USD
#   rotor_adder
#     rotor_cost                             [1292397.846]  USD
#     rotor_mass_tcc                         [103411.01]    kg
#   lss_c
#     lss_cost                               [371961.87]    USD
#   bearing_c
#     main_bearing_cost                      [43791.345]    USD
#   gearbox_c
#     gearbox_cost                           [390065.04]    USD
#   hss_c
#     hss_cost                               [10148.66]     USD
#   generator_c
#     generator_cost                         [207078.14]    USD
#   bedplate_c
#     bedplate_cost                          [269962.74]    USD
#   yaw_c
#     yaw_system_cost                        [98589.392]    USD
#   hvac_c
#     hvac_cost                              [124000.]      USD
#   controls_c
#     controls_cost                          [105750.]      USD
#   vs_c
#     vs_cost                                [18800.]       USD
#   elec_c
#     elec_cost                              [209250.]      USD
#   cover_c
#     cover_cost                             [5700.]        USD
#   other_c
#     other_cost                             [-22200.]      USD
#   transformer_c
#     transformer_cost                       [18800.]       USD
#   nacelle_adder
#     nacelle_cost                           [1895488.532]  USD
#     nacelle_mass_tcc                       [197387.45]    kg
#   tower_c
#     tower_parts_cost                       [1260221.1]    USD
#   tower_adder
#     tower_cost                             [1260221.1]    USD
#   turbine_c
#     turbine_mass_tcc                       [735357.46]    kg
#     turbine_cost                           [4448107.478]  USD
#     turbine_cost_kW                        [889.6214956]  USD/kW
#
#
# 0 Implicit Output(s) in 'model'
# -------------------------------
# [('sharedIndeps.machine_rating', {'value': array([5000.]), 'units': 'kW'}),
#  ('sharedIndeps.blade_mass', {'value': array([17650.67]), 'units': 'kg'}),
#  ('sharedIndeps.hub_mass', {'value': array([31644.5]), 'units': 'kg'}),
#  ('sharedIndeps.pitch_system_mass', {'value': array([17004.]), 'units': 'kg'}),
#  ('sharedIndeps.spinner_mass', {'value': array([1810.5]), 'units': 'kg'}),
#  ('sharedIndeps.lss_mass', {'value': array([31257.3]), 'units': 'kg'}),
#  ('sharedIndeps.bearings_mass', {'value': array([0.]), 'units': 'kg'}),
#  ('sharedIndeps.gearbox_mass', {'value': array([30237.6]), 'units': 'kg'}),
#  ('sharedIndeps.main_bearing_mass',
#   {'value': array([4865.705]), 'units': 'kg'}),
#  ('sharedIndeps.hss_mass', {'value': array([1492.45]), 'units': 'kg'}),
#  ('sharedIndeps.generator_mass', {'value': array([16699.85]), 'units': 'kg'}),
#  ('sharedIndeps.bedplate_mass', {'value': array([93090.6]), 'units': 'kg'}),
#  ('sharedIndeps.yaw_mass', {'value': array([11878.24]), 'units': 'kg'}),
#  ('sharedIndeps.vs_electronics_mass',
#   {'value': array([1000.]), 'units': 'kg'}),
#  ('sharedIndeps.hvac_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('sharedIndeps.cover_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('sharedIndeps.platforms_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('sharedIndeps.transformer_mass', {'value': array([1000.]), 'units': 'kg'}),
#  ('sharedIndeps.tower_mass', {'value': array([434559.]), 'units': 'kg'}),
#  ('indeps.blade_mass_cost_coeff', {'value': array([14.6]), 'units': 'USD/kg'}),
#  ('indeps.hub_mass_cost_coeff', {'value': array([3.9]), 'units': 'USD/kg'}),
#  ('indeps.pitch_system_mass_cost_coeff',
#   {'value': array([22.1]), 'units': 'USD/kg'}),
#  ('indeps.spinner_mass_cost_coeff',
#   {'value': array([11.1]), 'units': 'USD/kg'}),
#  ('indeps.lss_mass_cost_coeff', {'value': array([11.9]), 'units': 'USD/kg'}),
#  ('indeps.bearings_mass_cost_coeff',
#   {'value': array([4.5]), 'units': 'USD/kg'}),
#  ('indeps.gearbox_mass_cost_coeff',
#   {'value': array([12.9]), 'units': 'USD/kg'}),
#  ('indeps.hss_mass_cost_coeff', {'value': array([6.8]), 'units': 'USD/kg'}),
#  ('indeps.generator_mass_cost_coeff',
#   {'value': array([12.4]), 'units': 'USD/kg'}),
#  ('indeps.bedplate_mass_cost_coeff',
#   {'value': array([2.9]), 'units': 'USD/kg'}),
#  ('indeps.yaw_mass_cost_coeff', {'value': array([8.3]), 'units': 'USD/kg'}),
#  ('indeps.vs_electronics_mass_cost_coeff',
#   {'value': array([18.8]), 'units': 'USD/kg'}),
#  ('indeps.hvac_mass_cost_coeff', {'value': array([124.]), 'units': 'USD/kg'}),
#  ('indeps.cover_mass_cost_coeff', {'value': array([5.7]), 'units': 'USD/kg'}),
#  ('indeps.elec_connec_machine_rating_cost_coeff',
#   {'value': array([41.85]), 'units': 'USD/kW'}),
#  ('indeps.platforms_mass_cost_coeff',
#   {'value': array([17.1]), 'units': 'USD/kg'}),
#  ('indeps.base_hardware_cost_coeff',
#   {'value': array([0.7]), 'units': 'USD/kg'}),
#  ('indeps.transformer_mass_cost_coeff',
#   {'value': array([18.8]), 'units': 'USD/kg'}),
#  ('indeps.tower_mass_cost_coeff', {'value': array([2.9]), 'units': 'USD/kg'}),
#  ('indeps.controls_machine_rating_cost_coeff',
#   {'value': array([21.15]), 'units': 'USD/kW'}),
#  ('indeps.crane_cost', {'value': array([12000.]), 'units': 'USD'}),
#  ('indeps.hub_assemblyCostMultiplier', {'value': array([0.]), 'units': None}),
#  ('indeps.hub_overheadCostMultiplier', {'value': array([0.]), 'units': None}),
#  ('indeps.nacelle_assemblyCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('indeps.nacelle_overheadCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('indeps.tower_assemblyCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('indeps.tower_overheadCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('indeps.turbine_assemblyCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('indeps.turbine_overheadCostMultiplier',
#   {'value': array([0.]), 'units': None}),
#  ('indeps.hub_profitMultiplier', {'value': array([0.]), 'units': None}),
#  ('indeps.nacelle_profitMultiplier', {'value': array([0.]), 'units': None}),
#  ('indeps.tower_profitMultiplier', {'value': array([0.]), 'units': None}),
#  ('indeps.turbine_profitMultiplier', {'value': array([0.]), 'units': None}),
#  ('indeps.hub_transportMultiplier', {'value': array([0.]), 'units': None}),
#  ('indeps.nacelle_transportMultiplier', {'value': array([0.]), 'units': None}),
#  ('indeps.tower_transportMultiplier', {'value': array([0.]), 'units': None}),
#  ('indeps.turbine_transportMultiplier', {'value': array([0.]), 'units': None}),
#  ('blade_c.blade_cost', {'value': array([257699.782]), 'units': 'USD'}),
#  ('hub_c.hub_cost', {'value': array([123413.55]), 'units': 'USD'}),
#  ('pitch_c.pitch_system_cost', {'value': array([375788.4]), 'units': 'USD'}),
#  ('spinner_c.spinner_cost', {'value': array([20096.55]), 'units': 'USD'}),
#  ('hub_adder.hub_system_mass_tcc', {'value': array([50459.]), 'units': 'kg'}),
#  ('hub_adder.hub_system_cost', {'value': array([519298.5]), 'units': 'USD'}),
#  ('rotor_adder.rotor_cost', {'value': array([1292397.846]), 'units': 'USD'}),
#  ('rotor_adder.rotor_mass_tcc', {'value': array([103411.01]), 'units': 'kg'}),
#  ('lss_c.lss_cost', {'value': array([371961.87]), 'units': 'USD'}),
#  ('bearing_c.main_bearing_cost',
#   {'value': array([43791.345]), 'units': 'USD'}),
#  ('gearbox_c.gearbox_cost', {'value': array([390065.04]), 'units': 'USD'}),
#  ('hss_c.hss_cost', {'value': array([10148.66]), 'units': 'USD'}),
#  ('generator_c.generator_cost', {'value': array([207078.14]), 'units': 'USD'}),
#  ('bedplate_c.bedplate_cost', {'value': array([269962.74]), 'units': 'USD'}),
#  ('yaw_c.yaw_system_cost', {'value': array([98589.392]), 'units': 'USD'}),
#  ('hvac_c.hvac_cost', {'value': array([124000.]), 'units': 'USD'}),
#  ('controls_c.controls_cost', {'value': array([105750.]), 'units': 'USD'}),
#  ('vs_c.vs_cost', {'value': array([18800.]), 'units': 'USD'}),
#  ('elec_c.elec_cost', {'value': array([209250.]), 'units': 'USD'}),
#  ('cover_c.cover_cost', {'value': array([5700.]), 'units': 'USD'}),
#  ('other_c.other_cost', {'value': array([-22200.]), 'units': 'USD'}),
#  ('transformer_c.transformer_cost',
#   {'value': array([18800.]), 'units': 'USD'}),
#  ('nacelle_adder.nacelle_cost',
#   {'value': array([1895488.532]), 'units': 'USD'}),
#  ('nacelle_adder.nacelle_mass_tcc',
#   {'value': array([197387.45]), 'units': 'kg'}),
#  ('tower_c.tower_parts_cost', {'value': array([1260221.1]), 'units': 'USD'}),
#  ('tower_adder.tower_cost', {'value': array([1260221.1]), 'units': 'USD'}),
#  ('turbine_c.turbine_mass_tcc', {'value': array([735357.46]), 'units': 'kg'}),
#  ('turbine_c.turbine_cost', {'value': array([4448107.478]), 'units': 'USD'}),
#  ('turbine_c.turbine_cost_kW',
#   {'value': array([889.6214956]), 'units': 'USD/kW'}),
#  ('sharedIndeps.main_bearing_number', {'value': 2, 'units': ''}),
#  ('sharedIndeps.crane', {'value': True, 'units': ''})]
